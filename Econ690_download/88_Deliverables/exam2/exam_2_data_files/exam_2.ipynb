# %% [markdown]
# # Exam 2 (100 pts total)
#
# files needed = ('players.xlsx', 'CPS_March_2016.csv', 'euro_rate.csv', 'teams_ex2.csv', 'pwt_gdp.csv', 'pwt_emp.csv', 'ex_im.csv)
#
# You have 75 minutes to complete this exam.
#
# Answer all the questions below in this notebook. You should insert as many cells into the notebook as you need. When you are finished, upload your finished notebook to Canvas.
#
# You may use your notes and the Internet, but you cannot work with others.  Remember, jupyter notebooks and python have lots of built-in help facilities.
#
# **Import any packages you need to complete this exam.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 0 (5 pts): Your name
#
#
# 1. Replace 'Your name' above with your actual name. Enter it as: last name, first name.

# %% [markdown]
# ## Question 1 (5 pts)
# 1. Load the file 'players.xlsx' into a DataFrame named `players`.
# 2. Print out 10 random rows from `players`.

# %% [markdown]
# ## Question 2 (5 pts)
#
# Consider the two DataFrames `x` and `y`:
#
# ![dfs.png](attachment:dfs.png)

# %% [markdown]
# Insert a markdown cell below this one, give it a level-3 heading of 'Answers to question 2', and type in the answers to the following two questions.
#
# **You do not need to write any code to answer these questions.**
#
# Suppose I run the code:
# ```python
# z = pd.merge(left=X, right=Y, on='id', how='inner')
# ```
#
# 1. How many rows and columns are in `z`?
#
# Suppose I run the code:
# ```python
# z = pd.merge(left=X, right=Y, on='id', how='outer')
# ```
#
# 2. How many rows and columns are in `z`?

# %% [markdown]
# ## Question 3 (10 pts)
#
# 1. Load the file 'CPS_March_2016.csv' into a DataFrame named `wages`. Note that missing values in the file are '.'.
# 2. Rename the column 'fulltimely' to 'fulltime'.
# 3. Drop any rows in which 'hrwage'  is missing.
# 4. Keep only the rows in which 'fulltime' equals 1.
# 5. Cut the DataFrame into deciles. (i.e., 10 quantiles).
# 6. Print out the number of observations in each bin. They should be printed in ascending order of the bin, i.e., '(-0.001, 6.944]' should be first.

# %% [markdown]
# ## Question 4 (10 pts)
#
# 1. Create a DataFrame from the dictionary below. The data are populations in Wisconsin counties.
# 2. Create a vertical bar chart of the populations. Sort the bars, with the smallest county on the left.
# 3. Make the bars light grey.
# 4. Set the y-axis to range from 0 to 1 million.
# 5. Set the font sizes for the axes-tick labels to be 18.
# 6. Set the y-axis label to be 'population' in font size 18.
# 7. Remove the top and right spines.
#
# ```python
# data_dict = {'cty': ['Dane', 'Adams', 'Milwaukee', 'Rock'], 'pop': [542364, 20348, 948201, 163129]}
# ```

# %% [markdown]
# ## Question 5 (15 pts)
#
# 1. Load the file 'euro_rate.csv' into a DataFrame named `exrate`. The file contains the dollar-euro exchange rate: the number of dollars it takes to purchase one euro.
#
# 2. Rename 'DEXUSEU' to 'us_euro'.
#
# 2. Plot the **quarterly** average dollar-euro exchange rate. Make the figure 20  inches wide by 8 inches high.
#
# 3. Your plotted exchange rate peaks in 2018. Place the words 'peak depreciation' on your plot next to the peak of the line. Make the font size 14.
#
# 4. Label the y-axis 'dollars per euro'.

# %% [markdown]
# ## Question 6 (10 pts)
#
# 1. Load the file 'teams_ex2.csv' into a DataFrame named `teams`.
#
# Using pandas functions (no loops, no "manual" changes)
#
# 2. Make the elements in 'team' all capital letters.
# 3. Capitalize the first letter of each element in 'mascot'.
# 4. Create a new column named 'address' that contains strings of the form 'city, state'. Note the comma and the space that follows the comma.
# 5. Print out `teams`.

# %% [markdown]
# ## Question 7 (20 pts)
#
# 1. Load the file 'pwt_gdp.csv' into a DataFrame named `pwt1`.
# 2. Load the file 'pwt_emp.csv' into a DataFrame named `pwt2`.
# 3. Merge the two DataFrames into a new DataFrame named `pwt`. Use an outer merge. \[What is the unit of observation?\]

# %% [markdown]
# Insert a markdown cell below and answer the following questions. Give your markdown cell a level-3 title of 'Answer to question 7'.
#
# 4. How many observations were in both DataFrames?
# 5. How many observations were only in `pwt1`?
# 6. How many observations were only in `pwt2`?

# %% [markdown]
# ## Question 8 (20 pts)
#
# 1. Load the file 'ex_im.csv' into a DataFrame named `exim`. The file contains annual exports and imports by commodity for each U.S. state.
# 2. For each state-year-commodity, compute net exports: exports minus imports. \[You can do this however you prefer, but you probably want to reshape your DataFrame.\]
# 3. Make the DataFrame 'long' (or stacked) with the row index = \[state, commodity, year, var\] and a single column of values.
# 4. Sort the index.
# 5. Print out the first five rows of your DataFrame.
#
# The finished DataFrame should look like:
#
# ![stack.PNG](attachment:stack.PNG)

# %% [markdown]
# ### You are finished!
# Upload your completed notebook to Canvas. Have a good weekend.
